# %% [markdown]
# # Cleaning Data with Pandas Exercises
#
# For the exercises, you will be cleaning data in the Women's Clothing E-Commerce Reviews dataset.
#
# To start cleaning data, we first need to create a dataframe from the CSV and print out any relevant info to make sure our dataframe is ready to go.

# %%
# Import pandas and any other libraries you need here.
import pandas as pd 
import numpy as np
# Create a new dataframe from your CSV
df = pd.read_csv(r'Womens Clothing E-Commerce Reviews.csv')

# %%
# Print out any information you need to understand your dataframe
import pandas as pd
df = pd.read_csv(r'Womens Clothing E-Commerce Reviews.csv')
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB
# Index(['Unnamed: 0', 'Clothing ID', 'Age', 'Title', 'Review Text', 'Rating',
#        'Recommended IND', 'Positive Feedback Count', 'Division Name',
#        'Department Name', 'Class Name'],
#       dtype='object')

# %% [markdown]
# ## Missing Data
#
# Try out different methods to locate and resolve missing data.

# %%
# Try to find some missing data!
null_mask = df.isnull().any(axis=1)
null_rows = df[null_mask]
print(null_rows)

null_count = df.isnull().sum().sum()
print("Number of null values:", null_count)

df.dropna(how="all")
# Out:
#        Unnamed: 0  Clothing ID  Age Title  \
# 0               0          767   33   NaN
# 1               1         1080   34   NaN
# 11             11         1095   39   NaN
# 30             30         1060   33   NaN
# 36             36         1002   29   NaN
# ...           ...          ...  ...   ...
# 23450       23450          964   40   NaN
# 23453       23453         1104   39   NaN
# 23458       23458          862   63   NaN
# 23470       23470         1104   39   NaN
# 23480       23480          862   35   NaN
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 11     This dress is perfection! so pretty and flatte...       5
# 30     Beautifully made pants and on trend with the f...       5
# 36     This is a comfortable skirt that can span seas...       4
# ...                                                  ...     ...
# 23450  I wanted to love this jacket. so soft and grea...       3
# 23453  I am 5' 2" about 118 lbs. thought this fit rea...       4
# 23458  This is my new favorite sweater. it is lightwe...       5
# 23470                                                NaN       5
# 23480                                                NaN       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    1                        0       Initmates
# 1                    1                        4         General
# 11                   1                        2  General Petite
# 30                   1                        0  General Petite
# 36                   1                        5         General
# ...                ...                      ...             ...
# 23450                0                        4         General
# 23453                1                        0  General Petite
# 23458                1                        0  General Petite
# 23470                1                        0  General Petite
# 23480                1                        0  General Petite
#
#       Department Name Class Name
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 11            Dresses    Dresses
# 30            Bottoms      Pants
# 36            Bottoms     Skirts
# ...               ...        ...
# 23450         Jackets    Jackets
# 23453         Dresses    Dresses
# 23458            Tops      Knits
# 23470         Dresses    Dresses
# 23480            Tops      Knits
#
# [3824 rows x 11 columns]
# Number of null values: 4697
#        Unnamed: 0  Clothing ID  Age  \
# 0               0          767   33
# 1               1         1080   34
# 2               2         1077   60
# 3               3         1049   50
# 4               4          847   47
# ...           ...          ...  ...
# 23481       23481         1104   34
# 23482       23482          862   48
# 23483       23483         1104   31
# 23484       23484         1084   28
# 23485       23485         1104   52
#
#                                                    Title  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                Some major design flaws
# 3                                       My favorite buy!
# 4                                       Flattering shirt
# ...                                                  ...
# 23481                     Great dress for many occasions
# 23482                         Wish it was made of cotton
# 23483                              Cute, but see through
# 23484  Very cute dress, perfect for summer parties an...
# 23485                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND  Positive Feedback Count   Division Name  \
# 0                    1                        0       Initmates
# 1                    1                        4         General
# 2                    0                        0         General
# 3                    1                        0  General Petite
# 4                    1                        6         General
# ...                ...                      ...             ...
# 23481                1                        0  General Petite
# 23482                1                        0  General Petite
# 23483                0                        1  General Petite
# 23484                1                        2         General
# 23485                1                       22  General Petite
#
#       Department Name Class Name
# 0            Intimate  Intimates
# 1             Dresses    Dresses
# 2             Dresses    Dresses
# 3             Bottoms      Pants
# 4                Tops    Blouses
# ...               ...        ...
# 23481         Dresses    Dresses
# 23482            Tops      Knits
# 23483         Dresses    Dresses
# 23484         Dresses    Dresses
# 23485         Dresses    Dresses
#
# [23486 rows x 11 columns]

# %%
df.head(5)
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# Did you find any missing data? What things worked well for you and what did not?

# %%
# Respond to the above questions here: I did find missing data. Displaying the first five rows helped me understand what kind of data are stored in each column,
# and provided some context on what information the dataset gives us. I printed null rows to see which columns were missing data. 
# Lastly, I wanted to count the number of null values in the dataset.

# %% [markdown]
# ## Irregular Data
#
# With missing data out of the way, turn your attention to any outliers. Just as we did for missing data, we first need to detect the outliers.

# %%
# Keep an eye out for outliers!
import numpy as np
import pandas as pd 
df = pd.read_csv(r'Womens Clothing E-Commerce Reviews.csv')
# filter_df = df.loc[(df['Rating'] < 0) & (df['Rating'] > 5)]
# print(filter_df)

import matplotlib.pyplot as plt
clothing_rating = df.plot.hist(column="Rating")

# plt.scatter(x="Department_Name",y="Rating")
# plt.show()

# %% [markdown]
# What techniques helped you find outliers? In your opinion, what about the techniques you used made them effective?

# %%
# Make your notes here: I struggled to create a scatter plot. The histogram showed that the majority of ratings were 5.

# %% [markdown]
# ## Unnecessary Data
#
# Unnecessary data could be irrelevant to your analysis or a duplice column. Check out the dataset to see if there is any unnecessary data.

# %% [markdown]
# Did you find any unnecessary data in your dataset? How did you handle it?

# %%
# Look out for unnecessary data!
df.drop(columns=['Positive Feedback Count','Unnamed: 0','Class Name'])
# Out:
#        Clothing ID  Age                                              Title  \
# 0              767   33                                                NaN
# 1             1080   34                                                NaN
# 2             1077   60                            Some major design flaws
# 3             1049   50                                   My favorite buy!
# 4              847   47                                   Flattering shirt
# ...            ...  ...                                                ...
# 23481         1104   34                     Great dress for many occasions
# 23482          862   48                         Wish it was made of cotton
# 23483         1104   31                              Cute, but see through
# 23484         1084   28  Very cute dress, perfect for summer parties an...
# 23485         1104   52                    Please make more like this one!
#
#                                              Review Text  Rating  \
# 0      Absolutely wonderful - silky and sexy and comf...       4
# 1      Love this dress!  it's sooo pretty.  i happene...       5
# 2      I had such high hopes for this dress and reall...       3
# 3      I love, love, love this jumpsuit. it's fun, fl...       5
# 4      This shirt is very flattering to all due to th...       5
# ...                                                  ...     ...
# 23481  I was very happy to snag this dress at such a ...       5
# 23482  It reminds me of maternity clothes. soft, stre...       3
# 23483  This fit well, but the top was very see throug...       3
# 23484  I bought this dress for a wedding i have this ...       3
# 23485  This dress in a lovely platinum is feminine an...       5
#
#        Recommended IND   Division Name Department Name
# 0                    1       Initmates        Intimate
# 1                    1         General         Dresses
# 2                    0         General         Dresses
# 3                    1  General Petite         Bottoms
# 4                    1         General            Tops
# ...                ...             ...             ...
# 23481                1  General Petite         Dresses
# 23482                1  General Petite            Tops
# 23483                0  General Petite         Dresses
# 23484                1         General         Dresses
# 23485                1  General Petite         Dresses
#
# [23486 rows x 8 columns]

# %%
# Make your notes here. I got rid of some columns that seemed redundant or were unclear.

# %% [markdown]
# ## Inconsistent Data
#
# Inconsistent data is likely due to inconsistent formatting and can be addressed by re-formatting all values in a column or row.

# %%
# Look out for inconsistent data!
import pandas as pd
df = pd.read_csv(r'Womens Clothing E-Commerce Reviews.csv')
print(df.loc[:,'Recommended IND'])
df['Recommended IND'] = df['Recommended IND'].astype(bool)
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 23481    1
# 23482    1
# 23483    0
# 23484    1
# 23485    1
# Name: Recommended IND, Length: 23486, dtype: int64

# %% [markdown]
# Did you find any inconsistent data? What did you do to clean it?

# %%
# Make your notes here!
